# %% [markdown]
# ## 데이터 결합

# %% [markdown]
# ### Concat ( ) / Append( )

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
dff = pd.DataFrame({'Apple':[1, 2, 3],
                    'Bear':[1, 2, 3],
                    'Circle':[1, 2, 3]},
                    index = [1, 3, 5])
dft = pd.DataFrame({'Apple':[4, 5],
                    'Favour':[4, 5],
                    'Gear':[4, 5]},
                    index = [1, 4])
pd.concat([dff, dft], join='outer', axis=1)
# Out:
#    Apple  Bear  Circle  Apple  Favour  Gear
# 1    1.0   1.0     1.0    4.0     4.0   4.0
# 3    2.0   2.0     2.0    NaN     NaN   NaN
# 4    NaN   NaN     NaN    5.0     5.0   5.0
# 5    3.0   3.0     3.0    NaN     NaN   NaN

# %%
s1 = pd.Series(['a','b'], index = [1, 2])
s2 = pd.Series(['c','d'], index = [3, 4])
pd.concat([s1, s2])
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
def create_df(cols, idx):
    data = {c: [str(c.lower()) +str(i) for i in idx] for c in cols}
    return pd.DataFrame(data, idx)

# %%
df1 = create_df('AB',[1,2])
df1
# Out:
#     A   B
# 1  a1  b1
# 2  a2  b2

# %%
df2 = create_df('AB',[3, 4])
df2
# Out:
#     A   B
# 3  a3  b3
# 4  a4  b4

# %%
pd.concat([df1,df2])
# Index의 순서에 따라 아래로 데이터 테이블이 붙음
# Out:
#     A   B
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3
# 4  a4  b4

# %%
df_1 = pd.DataFrame(np.random.randint(1, 9, (3, 3)), index=['Apple', 'Bannana','Circle'], columns=[1, 2, 3])
df_2 = pd.DataFrame(np.random.randint(10, 19, (3, 3)), index=['Doll','Elevator','Fine'], columns=[1, 2, 3])
pd.concat([df_1, df_2], axis=1)
# Index의 순서에 따라 아래로 데이터 테이블이 붙었으며, 테이블당 없는 컬럼에 대해서는 NaN값으로 반환함
# axis = 1: Index의 공통적인 요소를 찾아 테이블을 붙이겠다.
# Out:
#             1    2    3     1     2     3
# Apple     1.0  3.0  2.0   NaN   NaN   NaN
# Bannana   1.0  4.0  1.0   NaN   NaN   NaN
# Circle    7.0  2.0  1.0   NaN   NaN   NaN
# Doll      NaN  NaN  NaN  17.0  15.0  18.0
# Elevator  NaN  NaN  NaN  10.0  15.0  13.0
# Fine      NaN  NaN  NaN  14.0  15.0  11.0

# %%
pd.concat([df_1, df_2])
# axis = 0: column의 공통적인 요소를 찾아 테이블을 붙이겠다.
# Out:
#            1   2   3
# Apple      1   3   2
# Bannana    1   4   1
# Circle     7   2   1
# Doll      17  15  18
# Elevator  10  15  13
# Fine      14  15  11

# %%
df_1 = pd.DataFrame(np.random.randint(1, 9, (3, 3)), index=['Apple', 'Bannana','Circle'], columns=[1, 2, 3])
df_2 = pd.DataFrame(np.random.randint(10, 19, (3, 3)), index=['Doll','Elevator','Fine'], columns=[4, 5, 6])
pd.concat([df_1, df_2])
# Index의 순서에 따라 아래로 데이터 테이블이 붙었으며, 테이블당 없는 컬럼에 대해서는 NaN값으로 반환함
# Out:
#             1    2    3     4     5     6
# Apple     6.0  5.0  8.0   NaN   NaN   NaN
# Bannana   7.0  1.0  5.0   NaN   NaN   NaN
# Circle    8.0  2.0  7.0   NaN   NaN   NaN
# Doll      NaN  NaN  NaN  13.0  13.0  13.0
# Elevator  NaN  NaN  NaN  14.0  18.0  14.0
# Fine      NaN  NaN  NaN  15.0  14.0  10.0

# %%
df3 = create_df('AB',[0,1])
df3
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1

# %%
df4 = create_df('CD',[0,1])
df4
# Out:
#     C   D
# 0  c0  d0
# 1  c1  d1

# %%
pd.concat([df3, df4])
# Out:
#      A    B    C    D
# 0   a0   b0  NaN  NaN
# 1   a1   b1  NaN  NaN
# 0  NaN  NaN   c0   d0
# 1  NaN  NaN   c1   d1

# %%
pd.concat([df3, df4], axis=1)
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1

# %%
df7 = create_df('AB', [0, 1])
df8 = create_df('AB', [2, 3])
pd.concat([df7, df8])
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3

# %%
pd.concat([df7, df8], axis =1)
# Out:
#      A    B    A    B
# 0   a0   b0  NaN  NaN
# 1   a1   b1  NaN  NaN
# 2  NaN  NaN   a2   b2
# 3  NaN  NaN   a3   b3

# %%
df_5 = pd.DataFrame({1:[1, 2, 3], 3:[4, 5, 6], 5:[7, 8, 9]},
                    index = [1, 2, 3])
df_6 = pd.DataFrame({1:[1, 3, 4], 2:[1, 1, 1], 4:[7, 8, 9]},
                    index = [1, 2, 3])
pd.concat([df_5, df_6])
# Out:
#    1    2    3    4    5
# 1  1  NaN  4.0  NaN  7.0
# 2  2  NaN  5.0  NaN  8.0
# 3  3  NaN  6.0  NaN  9.0
# 1  1  1.0  NaN  7.0  NaN
# 2  3  1.0  NaN  8.0  NaN
# 3  4  1.0  NaN  9.0  NaN

# %%
df_7 = pd.DataFrame({1:[1, 2, 3], 3:[4, 5, 6], 5:[7, 8, 9]})
df_8 = pd.DataFrame({2:[1, 1, 1], 4:[7, 8, 9], 6:[8, 9, 0]})
pd.concat([df_7, df_8])
# Out:
#      1    2    3    4    5    6
# 0  1.0  NaN  4.0  NaN  7.0  NaN
# 1  2.0  NaN  5.0  NaN  8.0  NaN
# 2  3.0  NaN  6.0  NaN  9.0  NaN
# 0  NaN  1.0  NaN  7.0  NaN  8.0
# 1  NaN  1.0  NaN  8.0  NaN  9.0
# 2  NaN  1.0  NaN  9.0  NaN  0.0

# %%
pd.concat([df_7, df_8], axis=1).sort_index(axis=1)
# Out:
#    1  2  3  4  5  6
# 0  1  1  4  7  7  8
# 1  2  1  5  8  8  9
# 2  3  1  6  9  9  0

# %%
pd.concat([df_5, df_6], axis=1).sort_index(axis=1)
# Out:
#    1  1  2  3  4  5
# 1  1  1  1  4  7  7
# 2  2  3  1  5  8  8
# 3  3  4  1  6  9  9

# %% [markdown]
# concat은 하나의 공통된 기준을 가지고 테이블을 합치는 것이다.
# 만약 공통된 기준이 존재하지 않으면 NaN값으로 채워진다.
# 공통된 기준은 axis를 기준으로 하며, 기본값은 axis=0다.<br>
# <br>
# axis=0: 두 테이블의 컬럼을 기준으로 합친다.
# axis=1: 두 테이블의 인덱스를 기준으로 합친다.

# %%
pd.concat([df_5, df_6], join='inner')
# Out:
#    1
# 1  1
# 2  2
# 3  3
# 1  1
# 2  3
# 3  4

# %%
pd.concat([df_5, df_6], join='inner', axis=1)
# Out:
#    1  3  5  1  2  4
# 1  1  4  7  1  1  7
# 2  2  5  8  3  1  8
# 3  3  6  9  4  1  9

# %%
df5 = create_df('ABC',[1, 2])
df6 = create_df('BCD',[3, 4])
pd.concat([df5, df6])
# Out:
#      A   B   C    D
# 1   a1  b1  c1  NaN
# 2   a2  b2  c2  NaN
# 3  NaN  b3  c3   d3
# 4  NaN  b4  c4   d4

# %%
pd.concat([df5, df6],join='inner')
# Out:
#     B   C
# 1  b1  c1
# 2  b2  c2
# 3  b3  c3
# 4  b4  c4
